# %%
import argparse
import os
import time
import copy
import six
import sys
import torch
import numpy as np

import torchvision.models as models
import matplotlib.pyplot as plt
from torch.utils.data.dataloader import DataLoader
### tensorboard

from torch.utils.tensorboard import SummaryWriter
from torch.optim import lr_scheduler

writer = SummaryWriter('runs/experiment_prior')
#######
sys.path.append('/home/jbonato/Documents/cvpr_clvision_challenge/')
from core50.dataset import CORE50
from utils.train_test import train_net, test_multitask, preprocess_imgs
from utils.common import create_code_snapshot,check_ext_mem, check_ram_usage

######
import torch.nn as nn
import torch
import numpy

from DIM_model import *
from train import *
from PP_misc.loader import LoadDataset,data_split,data_split_Tr_CV,LoadFeatures
from PP_misc.transf import * 
from model import classifier

from train_prior_disc import save_prior_dist


device = torch.device('cuda:0')
dataset = CORE50(root='/home/jbonato/Documents/cvpr_clvision_challenge/core50/data/', scenario='multi-task-nc',preload=True)
test =  dataset.get_full_valid_set(reduced=False)


# data_test = data_testf[labels_testf<5,:,:,:]
# labels_test = labels_testf[labels_testf<5]
# Out:
# Loading data...
# Loading paths...
# Loading LUP...
# Loading labels...
# preparing CL benchmark...

# %%
def convert_lab(labels,task,map_lb):
    if task!=0:
        case = map_lb[str(task)]
        print(case)
        if case == 'A':
            n_labels = labels%5
        if case =='B':
            n_labels = labels%5 + 5
        return n_labels
    else:
        return labels
def revert_lab(labels,task,map_lb):
    if task!=0:
        case = map_lb[str(task)]
        if case == 'A':
            n_labels = labels+task*5+5
        if case == 'B':
            n_labels = labels+task*5
        return n_labels
    else:
        return labels
case = {'0':None,'1':'B','2':'A','3':'B','4':'A','5':'A','6':'A','7':'B','8':'B'}

# %%
load = False
replay = True
train = True

stats = {"ram": [], "disk": []}

if train:
    tr = Transform(affine=0.5, train=True,cutout_ratio=0.6,ssr_ratio=0.6,flip = 0.6)
    for i, train_batch in enumerate(dataset):
        writerDIM = SummaryWriter('runs/experiment_DIM'+str(i))
        data,labelsI, t = train_batch
        labels = convert_lab(labelsI,t,case)
        index_tr,index_cv,coreset = data_split(data.shape[0],777)
        if i == 0:
            ext_mem = [data[coreset], labels[coreset]]
            dataC = np.concatenate((data[index_tr], data[index_cv]),axis=0)
            labC = np.concatenate((labels[index_tr],labels[index_cv]),axis=0)
        else:
            dataP = ext_mem[0]
            labP = ext_mem[1]

            ext_mem = [
                np.concatenate((data[coreset], ext_mem[0])),
                np.concatenate((labels[coreset], ext_mem[1]))]
            if replay:
                dataC = np.concatenate((data[index_tr], data[index_cv],dataP),axis=0)
                labC = np.concatenate((labels[index_tr],labels[index_cv],labP),axis=0)
            else:
                dataC = np.concatenate((data[index_tr], data[index_cv]),axis=0)
                labC = np.concatenate((labels[index_tr],labels[index_cv]),axis=0)
        
        stats['disk'].append(check_ext_mem("cl_ext_mem"))
        stats['ram'].append(check_ram_usage())
        
        print("----------- batch {0} -------------".format(i))
        print("Task Label: ", t)
        trC,cvC = data_split_Tr_CV(dataC.shape[0],777)

        train_set = LoadDataset(dataC,labC,transform=tr,indices=trC)
        val_set = LoadDataset(dataC,labC,transform=tr,indices=cvC)
        print('Training set: {0} \n Validation Set {1}'.format(train_set.__len__(),val_set.__len__()))
        batch_size=32
        train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
        valid_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
        dataloaders = {'train':train_loader,'val':valid_loader}

        if i ==0:        
            prior = False
            ep=80
            dim_model = DIM_model(batch_s=32,num_classes =128,feature=True)   
            dim_model.to(device)
            classifierM = classifier(n_input=128,n_class=10)
            classifierM = classifierM.to(device)
            writer = SummaryWriter('runs/experiment_C'+str(i))
            lr_new = 0.00001
            lrC=0.0001
            epC=50
        else:
            prior = True
            ep=8
            epC=10
            lr_new =0.000005
            lrC = 0.00005

        optimizer = torch.optim.Adam(dim_model.parameters(),lr=lr_new)
        scheduler = lr_scheduler.StepLR(optimizer,step_size=40,gamma=0.1) #there is also MultiStepLR
        tr_dict_enc = {'ep':ep,'writer':writerDIM,'best_loss':1e10,'t_board':True,'gamma':.5,'beta':.5,'Prior_Flag':prior,'discriminator':classifierM}    
        tr_dict_cl = {'ep':50,'writer':writer,'best_loss':1e10,'t_board':True,'gamma':1}

        if i==0 and load:
            print('Load DIM model weights first step')
            dim_model.load_state_dict(torch.load('/home/jbonato/Documents/cvpr_clvision_challenge/weights/weightsDIM_T0_NC_128.pt'))
        else:
            dim_model = trainEnc_MI(dim_model, optimizer, scheduler,dataloaders,device,tr_dict_enc)
            torch.save(dim_model.state_dict(), '/home/jbonato/Documents/cvpr_clvision_challenge/weights/weightsDIM_T'+str(i)+'_NC_128.pt')

        #if i==0:
        dataTr,labTr = save_prior_dist(dim_model,train_loader,device)
        dataCv,labCv = save_prior_dist(dim_model,valid_loader,device)

        print(dataTr.shape,labTr.shape)

        train_set = LoadFeatures(dataTr,labTr)
        val_set = LoadFeatures(dataCv,labCv)
        batch_size=32

        train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
        valid_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
        dataloaderC = {'train':train_loader,'val':valid_loader}
        
        optimizerC = torch.optim.Adam(classifierM.parameters(),lr=lrC)
        schedulerC = lr_scheduler.StepLR(optimizerC,step_size=40,gamma=0.1)
        classifierM.requires_grad_(True)
        classifierM = train_classifier(classifierM, optimizerC, schedulerC,dataloaderC,device,tr_dict_cl)
        torch.save(classifierM.state_dict(), '/home/jbonato/Documents/cvpr_clvision_challenge/weights/weightsC_T'+str(i)+'_NC_128.pt')
        
        stats['disk'].append(check_ext_mem("cl_ext_mem"))
        stats['ram'].append(check_ram_usage())
    ######## print mem 
        print('Memory usage',np.asarray(stats['ram']).mean())
    
    #### test Parte on coreset to undestand performance
        for jj in range(len(test)):
            data_test = test[jj][0][0]
            labels_test = test[jj][0][1]
            task = test[jj][1]
            
            test_set = LoadDataset(data_test,labels_test,transform=None)
            batch_size=100
            test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)
            score= []
            dim_model.eval()
            classifierM.eval()
            for inputs, labels in test_loader:
                torch.cuda.empty_cache()
                inputs = inputs.to(device)
                labels = labels.to(device) 
                _,_,ww =dim_model(inputs)
                pred = classifierM(ww)
                pred_l = pred.data.cpu().numpy()
                pred_l = np.argmax(pred_l,axis=1)
                out_lab = revert_lab(pred_l,task)
                score.append(np.sum(out_lab==labels.data.cpu().numpy())/out_lab.shape[0])
            print('TEST PERFORMANCES:', np.asarray(score).mean())
            del test_set,test_loader
# Out:
# Batch number: 0
# ----------- batch 0 -------------
# Task Label:  0
# Training set: 17265
#  Validation Set 4317
# Epoch 0/79
# ----------
# LR 1e-05
# train: MI_loss: 0.696479, loss: 0.696479
# val: MI_loss: -0.650472, loss: -0.650472
# saving best model
# 0m 54s
# Epoch 1/79
# ----------
# LR 1e-05
# train: MI_loss: -0.849518, loss: -0.849518
# val: MI_loss: -0.862436, loss: -0.862436
# saving best model
# 0m 53s
# Epoch 2/79
# ----------
# LR 1e-05
# train: MI_loss: -1.035216, loss: -1.035216
# val: MI_loss: -0.953299, loss: -0.953299
# saving best model
# 0m 53s
# Epoch 3/79
# ----------
# LR 1e-05
# train: MI_loss: -1.061694, loss: -1.061694
# val: MI_loss: -0.780108, loss: -0.780108
# 0m 52s
# Epoch 4/79
# ----------
# LR 1e-05
# train: MI_loss: -1.146139, loss: -1.146139
# val: MI_loss: -1.125726, loss: -1.125726
# saving best model
# 0m 52s
# Epoch 5/79
# ----------
# LR 1e-05
# train: MI_loss: -1.191928, loss: -1.191928
# val: MI_loss: -1.186787, loss: -1.186787
# saving best model
# 0m 53s
# Epoch 6/79
# ----------
# LR 1e-05
# train: MI_loss: -1.219992, loss: -1.219992
# val: MI_loss: -1.171180, loss: -1.171180
# 0m 53s
# Epoch 7/79
# ----------
# LR 1e-05
# train: MI_loss: -1.208656, loss: -1.208656
# val: MI_loss: -1.149545, loss: -1.149545
# 0m 53s
# Epoch 8/79
# ----------
# LR 1e-05
# train: MI_loss: -1.198983, loss: -1.198983
# val: MI_loss: -1.223793, loss: -1.223793
# saving best model
# 0m 53s
# Epoch 9/79
# ----------
# LR 1e-05
# train: MI_loss: -1.254281, loss: -1.254281
# val: MI_loss: -1.223080, loss: -1.223080
# 0m 53s
# Epoch 10/79
# ----------
# LR 1e-05
# train: MI_loss: -1.247296, loss: -1.247296
# val: MI_loss: -1.217949, loss: -1.217949
# 0m 50s
# Epoch 11/79
# ----------
# LR 1e-05
# train: MI_loss: -1.253421, loss: -1.253421
# val: MI_loss: -1.224798, loss: -1.224798
# saving best model
# 0m 51s
# Epoch 12/79
# ----------
# LR 1e-05
# train: MI_loss: -1.258543, loss: -1.258543
# val: MI_loss: -1.240327, loss: -1.240327
# saving best model
# 0m 54s
# Epoch 13/79
# ----------
# LR 1e-05
# train: MI_loss: -1.262103, loss: -1.262103
# val: MI_loss: -1.197723, loss: -1.197723
# 0m 52s
# Epoch 14/79
# ----------
# LR 1e-05
# train: MI_loss: -1.262524, loss: -1.262524
# val: MI_loss: -1.224418, loss: -1.224418
# 0m 53s
# Epoch 15/79
# ----------
# LR 1e-05
# train: MI_loss: -1.269801, loss: -1.269801
# val: MI_loss: -1.229349, loss: -1.229349
# 0m 53s
# Epoch 16/79
# ----------
# LR 1e-05
# train: MI_loss: -1.276241, loss: -1.276241
# val: MI_loss: -1.223209, loss: -1.223209
# 0m 53s
# Epoch 17/79
# ----------
# LR 1e-05
# train: MI_loss: -1.270428, loss: -1.270428
# val: MI_loss: -1.236546, loss: -1.236546
# 0m 49s
# Epoch 18/79
# ----------
# LR 1e-05
# train: MI_loss: -1.281702, loss: -1.281702
# val: MI_loss: -1.243194, loss: -1.243194
# saving best model
# 0m 53s
# Epoch 19/79
# ----------
# LR 1e-05
# train: MI_loss: -1.273865, loss: -1.273865
# val: MI_loss: -1.259055, loss: -1.259055
# saving best model
# 0m 53s
# Epoch 20/79
# ----------
# LR 1e-05
# train: MI_loss: -1.282079, loss: -1.282079
# val: MI_loss: -1.248992, loss: -1.248992
# 0m 53s
# Epoch 21/79
# ----------
# LR 1e-05
# train: MI_loss: -1.282136, loss: -1.282136
# val: MI_loss: -1.223744, loss: -1.223744
# 0m 53s
# Epoch 22/79
# ----------
# LR 1e-05
# train: MI_loss: -1.284055, loss: -1.284055
# val: MI_loss: -1.243506, loss: -1.243506
# 0m 53s
# Epoch 23/79
# ----------
# LR 1e-05
# train: MI_loss: -1.281372, loss: -1.281372
# val: MI_loss: -1.245073, loss: -1.245073
# 0m 50s
# Epoch 24/79
# ----------
# LR 1e-05
# train: MI_loss: -1.283973, loss: -1.283973
# val: MI_loss: -1.228490, loss: -1.228490
# 0m 50s
# Epoch 25/79
# ----------
# LR 1e-05
# train: MI_loss: -1.281491, loss: -1.281491
# val: MI_loss: -1.187347, loss: -1.187347
# 0m 53s
# Epoch 26/79
# ----------
# LR 1e-05
# train: MI_loss: -1.280748, loss: -1.280748
# val: MI_loss: -1.265264, loss: -1.265264
# saving best model
# 0m 53s
# Epoch 27/79
# ----------
# LR 1e-05
# train: MI_loss: -1.288172, loss: -1.288172
# val: MI_loss: -1.268466, loss: -1.268466
# saving best model
# 0m 54s
# Epoch 28/79
# ----------
# LR 1e-05
# train: MI_loss: -1.287343, loss: -1.287343
# val: MI_loss: -1.272431, loss: -1.272431
# saving best model
# 0m 53s
# Epoch 29/79
# ----------
# LR 1e-05
# train: MI_loss: -1.291405, loss: -1.291405
# val: MI_loss: -1.272542, loss: -1.272542
# saving best model
# 0m 54s
# Epoch 30/79
# ----------
# LR 1e-05
# train: MI_loss: -1.291794, loss: -1.291794
# val: MI_loss: -1.229445, loss: -1.229445
# 0m 52s
# Epoch 31/79
# ----------
# LR 1e-05
# train: MI_loss: -1.285142, loss: -1.285142
# val: MI_loss: -1.235662, loss: -1.235662
# 0m 52s
# Epoch 32/79
# ----------
# LR 1e-05
# train: MI_loss: -1.289276, loss: -1.289276
# val: MI_loss: -1.243840, loss: -1.243840
# 0m 52s
# Epoch 33/79
# ----------
# LR 1e-05
# train: MI_loss: -1.284155, loss: -1.284155
# val: MI_loss: -1.229857, loss: -1.229857
# 0m 53s
# Epoch 34/79
# ----------
# LR 1e-05
# train: MI_loss: -1.289901, loss: -1.289901
# val: MI_loss: -1.285011, loss: -1.285011
# saving best model
# 0m 52s
# Epoch 35/79
# ----------
# LR 1e-05
# train: MI_loss: -1.284326, loss: -1.284326
# val: MI_loss: -1.242827, loss: -1.242827
# 0m 50s
# Epoch 36/79
# ----------
# LR 1e-05
# train: MI_loss: -1.287938, loss: -1.287938
# val: MI_loss: -1.288146, loss: -1.288146
# saving best model
# 0m 53s
# Epoch 37/79
# ----------
# LR 1e-05
# train: MI_loss: -1.290225, loss: -1.290225
# val: MI_loss: -1.265485, loss: -1.265485
# 0m 53s
# Epoch 38/79
# ----------
# LR 1e-05
# train: MI_loss: -1.291202, loss: -1.291202
# val: MI_loss: -1.268777, loss: -1.268777
# 0m 53s
# Epoch 39/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.281729, loss: -1.281729
# val: MI_loss: -1.269268, loss: -1.269268
# 0m 53s
# Epoch 40/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.298273, loss: -1.298273
# val: MI_loss: -1.282948, loss: -1.282948
# 0m 52s
# Epoch 41/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299839, loss: -1.299839
# val: MI_loss: -1.283919, loss: -1.283919
# 0m 53s
# Epoch 42/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299053, loss: -1.299053
# val: MI_loss: -1.284723, loss: -1.284723
# 0m 53s
# Epoch 43/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300548, loss: -1.300548
# val: MI_loss: -1.279854, loss: -1.279854
# 0m 54s
# Epoch 44/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300834, loss: -1.300834
# val: MI_loss: -1.290467, loss: -1.290467
# saving best model
# 0m 52s
# Epoch 45/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300512, loss: -1.300512
# val: MI_loss: -1.277421, loss: -1.277421
# 0m 53s
# Epoch 46/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299961, loss: -1.299961
# val: MI_loss: -1.290536, loss: -1.290536
# saving best model
# 0m 53s
# Epoch 47/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.298879, loss: -1.298879
# val: MI_loss: -1.279467, loss: -1.279467
# 0m 53s
# Epoch 48/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.297097, loss: -1.297097
# val: MI_loss: -1.287455, loss: -1.287455
# 0m 53s
# Epoch 49/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.297659, loss: -1.297659
# val: MI_loss: -1.284553, loss: -1.284553
# 0m 53s
# Epoch 50/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.296976, loss: -1.296976
# val: MI_loss: -1.269171, loss: -1.269171
# 0m 53s
# Epoch 51/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.296907, loss: -1.296907
# val: MI_loss: -1.295969, loss: -1.295969
# saving best model
# 0m 53s
# Epoch 52/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299668, loss: -1.299668
# val: MI_loss: -1.288793, loss: -1.288793
# 0m 53s
# Epoch 53/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300789, loss: -1.300789
# val: MI_loss: -1.287356, loss: -1.287356
# 0m 52s
# Epoch 54/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300634, loss: -1.300634
# val: MI_loss: -1.289724, loss: -1.289724
# 0m 53s
# Epoch 55/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.305263, loss: -1.305263
# val: MI_loss: -1.300734, loss: -1.300734
# saving best model
# 0m 52s
# Epoch 56/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.297461, loss: -1.297461
# val: MI_loss: -1.295350, loss: -1.295350
# 0m 51s
# Epoch 57/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299410, loss: -1.299410
# val: MI_loss: -1.287506, loss: -1.287506
# 0m 53s
# Epoch 58/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299765, loss: -1.299765
# val: MI_loss: -1.285615, loss: -1.285615
# 0m 53s
# Epoch 59/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.303226, loss: -1.303226
# val: MI_loss: -1.292790, loss: -1.292790
# 0m 53s
# Epoch 60/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299966, loss: -1.299966
# val: MI_loss: -1.297297, loss: -1.297297
# 0m 53s
# Epoch 61/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.302115, loss: -1.302115
# val: MI_loss: -1.288048, loss: -1.288048
# 0m 50s
# Epoch 62/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.298509, loss: -1.298509
# val: MI_loss: -1.293245, loss: -1.293245
# 0m 49s
# Epoch 63/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300458, loss: -1.300458
# val: MI_loss: -1.278958, loss: -1.278958
# 0m 53s
# Epoch 64/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.298652, loss: -1.298652
# val: MI_loss: -1.288020, loss: -1.288020
# 0m 53s
# Epoch 65/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.304444, loss: -1.304444
# val: MI_loss: -1.299427, loss: -1.299427
# 0m 53s
# Epoch 66/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.298734, loss: -1.298734
# val: MI_loss: -1.296501, loss: -1.296501
# 0m 54s
# Epoch 67/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.297410, loss: -1.297410
# val: MI_loss: -1.296481, loss: -1.296481
# 0m 53s
# Epoch 68/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299250, loss: -1.299250
# val: MI_loss: -1.290377, loss: -1.290377
# 0m 54s
# Epoch 69/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.297961, loss: -1.297961
# val: MI_loss: -1.292461, loss: -1.292461
# 0m 53s
# Epoch 70/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.296537, loss: -1.296537
# val: MI_loss: -1.289553, loss: -1.289553
# 0m 53s
# Epoch 71/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299067, loss: -1.299067
# val: MI_loss: -1.285694, loss: -1.285694
# 0m 54s
# Epoch 72/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.299954, loss: -1.299954
# val: MI_loss: -1.294511, loss: -1.294511
# 0m 54s
# Epoch 73/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300130, loss: -1.300130
# val: MI_loss: -1.281984, loss: -1.281984
# 0m 52s
# Epoch 74/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.301511, loss: -1.301511
# val: MI_loss: -1.295370, loss: -1.295370
# 0m 53s
# Epoch 75/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.297506, loss: -1.297506
# val: MI_loss: -1.290798, loss: -1.290798
# 0m 53s
# Epoch 76/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.300219, loss: -1.300219
# val: MI_loss: -1.292460, loss: -1.292460
# 0m 54s
# Epoch 77/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.303325, loss: -1.303325
# val: MI_loss: -1.296707, loss: -1.296707
# 0m 53s
# Epoch 78/79
# ----------
# LR 1.0000000000000002e-06
# train: MI_loss: -1.301315, loss: -1.301315
# val: MI_loss: -1.293047, loss: -1.293047
# 0m 50s
# Epoch 79/79
# ----------
# LR 1.0000000000000002e-07
# train: MI_loss: -1.298961, loss: -1.298961
# val: MI_loss: -1.295647, loss: -1.295647
# 0m 49s
# Best val loss: -1.300734
# (17265, 128) (17265,)
# Epoch 0/49
# ----------
# LR 0.0001
# train: loss: 2.049657, accuracy: 0.294230
# val: loss: 1.658724, accuracy: 0.442577
# saving best model
# 0m 2s
# Epoch 1/49
# ----------
# LR 0.0001
# train: loss: 1.561709, accuracy: 0.470837
# val: loss: 1.455802, accuracy: 0.501836
# saving best model
# 0m 2s
# Epoch 2/49
# ----------
# LR 0.0001
# train: loss: 1.413010, accuracy: 0.519564
# val: loss: 1.362646, accuracy: 0.525239
# saving best model
# 0m 3s
# Epoch 3/49
# ----------
# LR 0.0001
# train: loss: 1.324709, accuracy: 0.542685
# val: loss: 1.311258, accuracy: 0.547047
# saving best model
# 0m 3s
# Epoch 4/49
# ----------
# LR 0.0001
# train: loss: 1.270973, accuracy: 0.560934
# val: loss: 1.271690, accuracy: 0.554733
# saving best model
# 0m 3s
# Epoch 5/49
# ----------
# LR 0.0001
# train: loss: 1.220867, accuracy: 0.577781
# val: loss: 1.239584, accuracy: 0.560496
# saving best model
# 0m 3s
# Epoch 6/49
# ----------
# LR 0.0001
# train: loss: 1.189101, accuracy: 0.583650
# val: loss: 1.222057, accuracy: 0.567952
# saving best model
# 0m 2s
# Epoch 7/49
# ----------
# LR 0.0001
# train: loss: 1.163223, accuracy: 0.591163
# val: loss: 1.197150, accuracy: 0.577187
# saving best model
# 0m 2s
# Epoch 8/49
# ----------
# LR 0.0001
# train: loss: 1.131283, accuracy: 0.603101
# val: loss: 1.182778, accuracy: 0.579989
# saving best model
# 0m 2s
# Epoch 9/49
# ----------
# LR 0.0001
# train: loss: 1.111918, accuracy: 0.607217
# val: loss: 1.168978, accuracy: 0.580915
# saving best model
# 0m 2s
# Epoch 10/49
# ----------
# LR 0.0001
# train: loss: 1.085674, accuracy: 0.618256
# val: loss: 1.159804, accuracy: 0.589919
# saving best model
# 0m 2s
# Epoch 11/49
# ----------
# LR 0.0001
# train: loss: 1.068111, accuracy: 0.623196
# val: loss: 1.150223, accuracy: 0.589735
# saving best model
# 0m 2s
# Epoch 12/49
# ----------
# LR 0.0001
# train: loss: 1.050638, accuracy: 0.628823
# val: loss: 1.143273, accuracy: 0.592257
# saving best model
# 0m 2s
# Epoch 13/49
# ----------
# LR 0.0001
# train: loss: 1.033508, accuracy: 0.633786
# val: loss: 1.134955, accuracy: 0.595961
# saving best model
# 0m 2s
# Epoch 14/49
# ----------
# LR 0.0001
# train: loss: 1.022678, accuracy: 0.636244
# val: loss: 1.126684, accuracy: 0.598507
# saving best model
# 0m 2s
# Epoch 15/49
# ----------
# LR 0.0001
# train: loss: 1.005611, accuracy: 0.643321
# val: loss: 1.124670, accuracy: 0.598970
# saving best model
# 0m 2s
# Epoch 16/49
# ----------
# LR 0.0001
# train: loss: 0.993195, accuracy: 0.649571
# val: loss: 1.114898, accuracy: 0.600359
# saving best model
# 0m 2s
# Epoch 17/49
# ----------
# LR 0.0001
# train: loss: 0.978395, accuracy: 0.653615
# val: loss: 1.110731, accuracy: 0.602882
# saving best model
# 0m 2s
# Epoch 18/49
# ----------
# LR 0.0001
# train: loss: 0.968171, accuracy: 0.657455
# val: loss: 1.109331, accuracy: 0.601748
# saving best model
# 0m 2s
# Epoch 19/49
# ----------
# LR 0.0001
# train: loss: 0.951552, accuracy: 0.663879
# val: loss: 1.108375, accuracy: 0.604502
# saving best model
# 0m 2s
# Epoch 20/49
# ----------
# LR 0.0001
# train: loss: 0.944277, accuracy: 0.665152
# val: loss: 1.106123, accuracy: 0.607535
# saving best model
# 0m 2s
# Epoch 21/49
# ----------
# LR 0.0001
# train: loss: 0.931150, accuracy: 0.667330
# val: loss: 1.097523, accuracy: 0.606378
# saving best model
# 0m 2s
# Epoch 22/49
# ----------
# LR 0.0001
# train: loss: 0.917716, accuracy: 0.675303
# val: loss: 1.100602, accuracy: 0.602905
# 0m 2s
# Epoch 23/49
# ----------
# LR 0.0001
# train: loss: 0.910796, accuracy: 0.677182
# val: loss: 1.097717, accuracy: 0.606378
# 0m 2s
# Epoch 24/49
# ----------
# LR 0.0001
# train: loss: 0.900443, accuracy: 0.681601
# val: loss: 1.093025, accuracy: 0.602211
# saving best model
# 0m 2s
# Epoch 25/49
# ----------
# LR 0.0001
# train: loss: 0.890045, accuracy: 0.685393
# val: loss: 1.093971, accuracy: 0.602674
# 0m 2s
# Epoch 26/49
# ----------
# LR 0.0001
# 0m 2s
# Epoch 46/49
# ----------
# LR 5e-06
# train: loss: 0.669678, accuracy: 0.754664
# val: loss: 0.759645, accuracy: 0.718694
# 0m 3s
# Epoch 47/49
# ----------
# LR 5e-06
# train: loss: 0.668288, accuracy: 0.754039
# val: loss: 0.758852, accuracy: 0.719389
# 0m 2s
# Epoch 48/49
# ----------
# LR 5e-06
# train: loss: 0.670034, accuracy: 0.753866
# val: loss: 0.757726, accuracy: 0.718926
# 0m 2s
# Epoch 49/49
# ----------
# LR 5e-06
# train: loss: 0.667037, accuracy: 0.753067
# val: loss: 0.758801, accuracy: 0.718231
# 0m 2s
# Best val loss: 0.749232
# Memory usage 28666.39279513889
# TEST PERFORMANCES: 0.8941111111111111
# TEST PERFORMANCES: 0.8806666666666667
# TEST PERFORMANCES: 0.006
# TEST PERFORMANCES: 0.9051111111111112
# TEST PERFORMANCES: 0.005111111111111111
# TEST PERFORMANCES: 0.011777777777777778
# TEST PERFORMANCES: 0.0022222222222222222
# TEST PERFORMANCES: 0.8606296296296297
# TEST PERFORMANCES: 0.8982222222222221
# Batch number: 9

# %% [markdown]
# # Test

# %%
dim_model = DIM_model(batch_s=32,num_classes =128,feature=True)   
dim_model.to(device)
classifierM = classifier(n_input = 128,n_class=10)
classifierM = classifierM.to(device)
print('Load DIM model weights first step')
errors = np.zeros((50,))
final = []
for i in [8]:#range(8):
    final = []
    dim_model.load_state_dict(torch.load('/home/jbonato/Documents/cvpr_clvision_challenge/weights/weightsDIM_T'+str(i)+'_NC_128.pt'))    
    classifierM.load_state_dict(torch.load('/home/jbonato/Documents/cvpr_clvision_challenge/weights/weightsC_T'+str(i)+'_NC_128.pt'))
    for jj in range(len(test)):
        data_test = test[jj][0][0]
        labels_test = test[jj][0][1]
        task = test[jj][1]

        test_set = LoadDataset(data_test,labels_test,transform=None)
        batch_size=100
        test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)
        score= []
        dim_model.eval()
        classifierM.eval()
        for inputs, labels in test_loader:
            torch.cuda.empty_cache()
            inputs = inputs.to(device)
            labels = labels.to(device) 
            _,_,ww =dim_model(inputs)
            pred = classifierM(ww)
            pred_l = pred.data.cpu().numpy()
            pred_l = np.argmax(pred_l,axis=1)
            out_lab = revert_lab(pred_l,task,case)
            score.append(np.sum(out_lab==labels.data.cpu().numpy())/out_lab.shape[0])
        print('TEST PERFORMANCES:', np.asarray(score).mean())
        final.append(np.asarray(score).mean())
    print(np.asarray(final).mean())
# print(errors)

# a,b = np.unique(labels_test,True)
# print(a)
# print(b)
# Out:
# Load DIM model weights first step
# TEST PERFORMANCES: 0.8941111111111111
# TEST PERFORMANCES: 0.8806666666666667
# TEST PERFORMANCES: 0.8866666666666669
# TEST PERFORMANCES: 0.9051111111111112
# TEST PERFORMANCES: 0.8666666666666665
# TEST PERFORMANCES: 0.8499999999999999
# TEST PERFORMANCES: 0.8890526315789474
# TEST PERFORMANCES: 0.8606296296296297
# TEST PERFORMANCES: 0.8982222222222221
# 0.8812363006281135
